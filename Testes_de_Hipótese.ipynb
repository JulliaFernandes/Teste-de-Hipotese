# %% [markdown]
# # TESTE DE HIPÓTESES EM PYTHON
#
# Bootcamp data analytics Womakerscode
#
# O objetivo deste notebook é auxiliar o entendimento em como realizar testes: Qui Quadrado, ANOVA, KS e QQ Plots, conteudos abordados nas aulas do bootcamp

# %%
#### importando os pacotes
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## TESTE QUI-QUADRADO PARA ASSOCIAÇÕES DE VARIÁVEIS CATEGÓRICAS

# %%
from tabulate import tabulate ## para fazer tabelas

### gerando uma tabela t como exmeplo de visualizacao
t = [['Male', 'Car'],
         ['Male', 'Car'],
         ['Male', 'Motorcycle'],
         ['Female', 'Car'],
         ['Female', 'Bike']]

### exemplo da funcao tabulate
print(tabulate(t, headers= ['Gender','Vehicle'],
               tablefmt = 'fancy_grid', ## Formato da tabela
               stralign='center', 
               numalign='center',
               floatfmt=".2f")) ## Formato dos numeros, se é float, int, etc
# Out:
# ╒══════════╤════════════╕
# │  Gender  │  Vehicle   │
# ╞══════════╪════════════╡
# │   Male   │    Car     │
# ├──────────┼────────────┤
# │   Male   │    Car     │
# ├──────────┼────────────┤
# │   Male   │ Motorcycle │
# ├──────────┼────────────┤
# │  Female  │    Car     │
# ├──────────┼────────────┤
# │  Female  │    Bike    │
# ╘══════════╧════════════╛

# %% [markdown]
# ### 1. Criando a tabela de contingencia

# %%
#### criando uma tabela de contingencia como exmeplo
print(tabulate([['Male',9,18,28], ['Female',5,8,15]],
               headers = ['Car', 'Motorcycle', 'Bike'],
               tablefmt = 'fancy_grid',stralign='center',
               numalign='center',
               floatfmt=".2f"))
# Out:
# ╒════════╤═══════╤══════════════╤════════╕
# │        │  Car  │  Motorcycle  │  Bike  │
# ╞════════╪═══════╪══════════════╪════════╡
# │  Male  │   9   │      18      │   28   │
# ├────────┼───────┼──────────────┼────────┤
# │ Female │   5   │      8       │   15   │
# ╘════════╧═══════╧══════════════╧════════╛

# %%
#plot da tabela com cores
table = [[9, 18, 28],
         [5,  8,  15]]
plt.figure(figsize=(12,8))
x_axis_labels = ['Car', 'Motorcycle','Bike']
y_axis_labels = ['Male', 'Female']
sns.heatmap(table, annot=True, cmap="YlGnBu",xticklabels=x_axis_labels, yticklabels=y_axis_labels)
# Out:
# <Axes: >

# %% [markdown]
# Ambos os generos preferem bicicleta vamos entender se existe uma associação de genero ou nao

# %% [markdown]
# ### 2. Formulando as hipóteses
#
# H0 : As variaveis nao tem grau de associacao
# HA : As variáveis possuem grau de associação.
#
# Nivel de significancia, alpha = 0.05 (5%).

# %% [markdown]
# ###3. RODANDO O TESTE

# %%
# vamos rodar o teste utilizando a função chi2_contingency() do pacote SciPy, essa função roda o qui-quadrado para associação de variáveis, ai passa para ela a tabela de contingencia
from scipy.stats import chi2_contingency
from scipy.stats import chi2

estatistica, pvalor, df, expected = chi2_contingency(table)

alpha = 0.05 ## nivel de significancia

print(pvalor)
if pvalor <= alpha:
    print('Dependentes (rejeita H0)') ## Rejeita a hipotese nula, eles tem um grau de associação, são dependentes
else:
    print('Independentes (nao rejeita H0)') ## São independentes, não tem associação, não rejeita a hipotese nula
# Out:
# 0.9267147440706386
# Independentes (nao rejeita H0)

# %% [markdown]
# Como deu independentes podemos dizer que não ha uma associação do tipo de veiculo com o genero

# %% [markdown]
# ## TESTE ANOVA

# %% [markdown]
# Vamos realizar um teste ANOVA para média de idade de diferentes regioes de clientes de determinada rede de farmácias

# %% [markdown]
# O teste ANOVA ve se a média de diferentes grupos é estatisticamente diferente

# %%
### GERANDO OS DADOS
import scipy.stats as stats

np.random.seed(12)

regioes =   ["sul","sudeste","centro_oeste","norte","nordeste"]

# gerando dados aleatorios com python
consum_reg = np.random.choice(a= regioes,
                              p = [0.05, 0.15 ,0.25, 0.05, 0.5],
                              size=1000)

consum_idade = stats.poisson.rvs(loc=18, ## Gerando dados de idade que esta centralizado em 30 anos
                              mu=30, 
                              size=1000)

# %%
# agrupando os dados por regiao
consum_frame = pd.DataFrame({"reg":consum_reg,"idade":consum_idade})
groupos = consum_frame.groupby("reg").groups

# extraindo a idade de cada um dos grupos
sul = consum_idade[groupos["sul"]] ## Forma uma lista com todas as idades da regiao sul
sudeste = consum_idade[groupos["sudeste"]]
centro_oeste = consum_idade[groupos["centro_oeste"]]
norte = consum_idade[groupos["norte"]]
nordeste = consum_idade[groupos["nordeste"]]

# Perform the ANOVA
stats.f_oneway(sul, sudeste, centro_oeste, norte, nordeste)
# Out:
# F_onewayResult(statistic=np.float64(1.7744689357329695), pvalue=np.float64(0.13173183201930463))

# %%
consum_frame
# Out:
#               reg  idade
# 0         sudeste     51
# 1        nordeste     49
# 2    centro_oeste     51
# 3        nordeste     48
# 4             sul     56
# ..            ...    ...
# 995      nordeste     47
# 996           sul     40
# 997      nordeste     50
# 998      nordeste     51
# 999  centro_oeste     43
#
# [1000 rows x 2 columns]

# %% [markdown]
# Como o hipotese nula do teste é de que nao ha diferenca entre os grupos,
# como o p-valor é maior que 0.05 nao podemos rejeitar H0, e entao nao há diferenca de idade entre os grupos estatisticamente diferente.
#
# Os moradores da regiao sul, suldeste, cnetro-oeste etc, tem uma idade mais ou menos proxima

# %% [markdown]
# ## TESTE KS

# %% [markdown]
# Teste KS é um teste nao parametrico para ver o quao distante a misnha distribuição amostral esta da distribuição de referencia

# %%
# Generando 10000 pontos de uma distribuicao normal
rvs = stats.norm.rvs(size=10000)
sns.set_style('whitegrid')
# sns.kdeplot(rvs)
sns.distplot(rvs).set_title("Exemplo: Distribuiçao Normal")
plt.show()
# Out:
# /tmp/ipykernel_479563/2955866711.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(rvs).set_title("Exemplo: Distribuiçao Normal")

# %% [markdown]
# Rodando um teste KS para comparar os dados gerados com uma distribuição normal com o teste KS

# %%
stats.kstest(rvs=rvs, cdf='norm')
# Out:
# KstestResult(statistic=np.float64(0.005428053253586029), pvalue=np.float64(0.9282715152505315), statistic_location=np.float64(-0.10453613535027459), statistic_sign=np.int8(1))

# %% [markdown]
# A hipótese nula do teste é de que a distribuição dos dados segue a mesma da distribuição de referencia.
#
# Sendo assim como o pvalor é maior que 0.05, temos para um nivel de significancia de 5%, nao podemos rejeitar a hipotese nula, os dados se assemelham muito a distribuição normal
#
# ### Vamos rodar o mesmo teste agora para a variável idade gerada com a distribuicao de poisson no teste anterior

# %%
### gerando a variavel idade com a distribuicao de poisson
consum_idade = stats.poisson.rvs(loc=18,
                              mu=30,
                              size=15) ## Quanto mais size mais se assemelha a uma distribuicao normal
sns.distplot(consum_idade).set_title("Exemplo: Distribuiçao idade, poisson")
plt.show()
# Out:
# /tmp/ipykernel_479563/1507715472.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(consum_idade).set_title("Exemplo: Distribuiçao idade, poisson")

# %%
### roda o teste ks
stats.kstest(rvs=consum_idade, cdf='norm')
# Out:
# KstestResult(statistic=np.float64(1.0), pvalue=np.float64(0.0), statistic_location=np.int64(42), statistic_sign=np.int8(-1))

# %% [markdown]
#  hipótese nula do teste é de que a distribuição dos dados segue a mesma da distribuição de referencia. Signifca que o pvalue é menor que o nivel se signficancia de 0.05
#
# Sendo assim como o pvalor é menor que 0.05, temos para um nivel de significancia de 5%, rejeitamos a hipotese nula, e o dado nao segue a distribuicao normal pelo teste

# %% [markdown]
# ### QQ PLOTS

# %%
import statsmodels.api as sm

sm.qqplot(consum_idade)
plt.title("QQ PLOT - Idade")
plt.show()

# %% [markdown]
# Nao segue muito bem uma reta de 45° nao é muito uma distribuição geometrica

# %%
sm.qqplot(rvs)
plt.title("QQ PLOT - Normal")
plt.show()
